# %%
import os
os.chdir("..")

# %%
import pandas as pd

from utils import loaders

# %%
currency_pair = "btcusd"
loaders.populate_dataset(currency_pair, n_requests=100)

# %%
df = pd.read_pickle(f"database/{currency_pair}.pkl")

# %%
df.high.plot()
