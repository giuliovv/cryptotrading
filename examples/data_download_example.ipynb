# %%
import os
os.chdir("..")

# %%
import pandas as pd

from utils import loaders

# %%
currency_pair = "btceur"
loaders.populate_dataset(currency_pair, n_requests=300)
# Out:
# response:
# {"data": {"pair": "BTC/EUR", "ohlc": [{"high": "40129.19", "timestamp": "1613412000", "volume": "1.12424674", "low": "40041.20", "close": "40066.12", "open": "40041.20"}]}}
# Currency pair not found in the database, creating new dataset...
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))

# %%
df = pd.read_pickle(f"database/{currency_pair}.pkl")

# %%
df.high.plot()
